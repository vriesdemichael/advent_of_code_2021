# %%
from pathlib import Path

# %%
real_input = Path("../input_data/16").read_text()

# %%
test_input1 = "8A004A801A8002F478"
test_input2 = "620080001611562C8802118E34"
test_input3 = "C0015000016115A2E0802F182340"
test_input4 = "A0016C880162017C3686B18A3D4780"

# %%
def hex_to_bin(hex_string):
    binmap = {
        "0": "0000",
        "1": "0001",
        "2": "0010",
        "3": "0011",
        "4": "0100",
        "5": "0101",
        "6": "0110",
        "7": "0111",
        "8": "1000",
        "9": "1001",
        "A": "1010",
        "B": "1011",
        "C": "1100",
        "D": "1101",
        "E": "1110",
        "F": "1111",
    }
    return "".join([binmap[char] for char in hex_string])


def dec_to_bin(decimal_number, leading_zeros=4):
    if leading_zeros:
        return f"{decimal_number:0{leading_zeros}b}"
    else:
        return f"{decimal_number:#b}"

# %%
binary_representation = dec_to_bin(int(real_input, 16), 4)

# %%
print_enabled = True


def print_toggle(item):
    if print_enabled:
        print(item)


class Packet:
    subpkg_order = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"

    def __init__(self, binary_string, pid="0"):
        try:
            print_toggle(f"Creating packet {pid} from {binary_string}")
            self.binary_string = binary_string
            self.i = 0
            self.annotation = ""

            self.pid = pid
            self.subpackets = []

            self.version = int(binary_string[self.i: self.i + 3], 2)
            self.i += 3
            self.annotation += "VVV"

            self.package_type = int(binary_string[self.i: self.i + 3], 2)
            self.i += 3
            self.annotation += "TTT"

            print(f"Header of {self.pid} {self.version=} {self.package_type=}")

            if self.package_type == 4:

                print_toggle("Found a packet of type 4")
                packet_payload = ""
                final_block_found = False

                while not final_block_found:
                    print_toggle(f"Searching block {binary_string[self.i:self.i + 5]}")
                    final_block_found = binary_string[self.i] == "0"
                    self.i += 1

                    packet_payload += binary_string[self.i: self.i + 4]
                    self.i += 4

                    self.annotation += self.subpkg_order[int(len(packet_payload) / 4) - 1] * 5

                self.value = int(packet_payload, 2)

            else:
                length_type_id = binary_string[self.i]
                self.annotation += "I"
                self.i += 1

                if length_type_id == "1":
                    n_subpackets = int(self.binary_string[self.i: self.i + 11], 2)
                    self.annotation += "L" * 11
                    self.i += 11

                    print_toggle(f"Must find {n_subpackets} subpackets.")
                    for _ in range(n_subpackets):
                        subpacket_string = self.binary_string[self.i:]
                        subpacket = Packet(subpacket_string, pid=self.pid + f"_{len(self.subpackets)}")
                        print(f"Added {subpacket} to {self}")
                        self.i += subpacket.i
                        self.annotation += subpacket.annotation
                        self.subpackets.append(subpacket)

                elif length_type_id == "0":
                    n_bits = int(binary_string[self.i: self.i + 15], 2)
                    self.annotation += "L" * 15
                    self.i += 15

                    while n_bits > 0 and "1" in self.binary_string[self.i: self.i + n_bits]:
                        subpacket_string = self.binary_string[self.i: self.i + n_bits]
                        subpacket = Packet(subpacket_string, pid=self.pid + f"_{len(self.subpackets)}")
                        print(f"Added {subpacket} to {self}")
                        n_bits -= subpacket.i
                        self.i += subpacket.i
                        self.annotation += subpacket.annotation
                        self.subpackets.append(subpacket)

        except Exception as e:
            if self.pid == "0":
                print(e)
                print_packets([self])
            raise

    def compute(self):
        """
        Calculations for part 2
        """
        match self.package_type:
            case 0:  # sum
                return sum([p.compute() for p in self.subpackets])
            case 1:  # product
                product = self.subpackets[0].compute()
                for subpacket in self.subpackets[1:]:
                    product *= subpacket.compute()
                return product
            case 2:  # min
                return min([p.compute() for p in self.subpackets])
            case 3:  # max
                return max([p.compute() for p in self.subpackets])
            case 4:
                return self.value
            # TODO 5-7
            case 5:  # >
                first, second  = self.subpackets[0].compute(), self.subpackets[1].compute()
                return int(first > second)
            case 6:  # <
                first, second  = self.subpackets[0].compute(), self.subpackets[1].compute()
                return int(first < second)
            case 7:  # ==
                first, second  = self.subpackets[0].compute(), self.subpackets[1].compute()
                return int(first == second)


    def version_sum(self):
        return self.version + sum([sp.version_sum() for sp in self.subpackets])

    def __repr__(self):
        return f"<Packet version={self.version} package_type={self.package_type} {self.value if self.package_type == 4 else ''} {self.pid=}>"

# %%
def print_packets(packets, original_length=None):
    if not original_length:
        original_length = len(packets[0].binary_string)

    for packet in packets:
        indent = original_length - len(packet.binary_string)
        print(" " * indent + str(packet))
        print(" " * indent + packet.binary_string)
        print(" " * indent + packet.annotation)
        print_packets(packet.subpackets, original_length=original_length)

# %%
samples = {
    ("110100101111111000101000", 6),
    ("00111000000000000110111101000101001010010001001000000000", 9),
    (hex_to_bin("8A004A801A8002F478"), 16),
    (hex_to_bin("620080001611562C8802118E34"), 12),
    (hex_to_bin("C0015000016115A2E0802F182340"), 23),
    (hex_to_bin("A0016C880162017C3686B18A3D4780"), 31),
}

# %%
for n, (bin_string, expected_version_sum) in enumerate(samples):
    print(f"Package {n}")
    p = Packet(bin_string)
    print_packets([p])
    version_sum = p.version_sum()
    print(f"{version_sum=} {expected_version_sum=}")
    print("----")
    if expected_version_sum != version_sum:
        print(f"Wrong version sum {expected_version_sum=} {version_sum=}")
# Out:
# Package 0
# Creating packet 0 from 00111000000000000110111101000101001010010001001000000000
# Header of 0 self.version=1 self.package_type=6
# Creating packet 0_0 from 110100010100101001000100100
# Header of 0_0 self.version=6 self.package_type=4
# Found a packet of type 4
# Searching block 01010
# Added <Packet version=6 package_type=4 10 self.pid='0_0'> to <Packet version=1 package_type=6  self.pid='0'>
# Creating packet 0_1 from 0101001000100100
# Header of 0_1 self.version=2 self.package_type=4
# Found a packet of type 4
# Searching block 10001
# Searching block 00100
# Added <Packet version=2 package_type=4 20 self.pid='0_1'> to <Packet version=1 package_type=6  self.pid='0'>
# <Packet version=1 package_type=6  self.pid='0'>
# 00111000000000000110111101000101001010010001001000000000
# VVVTTTILLLLLLLLLLLLLLLVVVTTTAAAAAVVVTTTAAAAABBBBB
#                              <Packet version=6 package_type=4 10 self.pid='0_0'>
#                              110100010100101001000100100
#                              VVVTTTAAAAA
#                                         <Packet version=2 package_type=4 20 self.pid='0_1'>
#                                         0101001000100100
#                                         VVVTTTAAAAABBBBB
# version_sum=9 expected_version_sum=9
# ----
# Package 1
# Creating packet 0 from 110100101111111000101000
# Header of 0 self.version=6 self.package_type=4
# Found a packet of type 4
# Searching block 10111
# Searching block 11110
# Searching block 00101
# <Packet version=6 package_type=4 2021 self.pid='0'>
# 110100101111111000101000
# VVVTTTAAAAABBBBBCCCCC
# version_sum=6 expected_version_sum=6
# ----
# Package 2
# Creating packet 0 from 100010100000000001001010100000000001101010000000000000101111010001111000
# Header of 0 self.version=4 self.package_type=2
# Must find 1 subpackets.
# Creating packet 0_0 from 001010100000000001101010000000000000101111010001111000
# Header of 0_0 self.version=1 self.package_type=2
# Must find 1 subpackets.
# Creating packet 0_0_0 from 101010000000000000101111010001111000
# Header of 0_0_0 self.version=5 self.package_type=2
# Creating packet 0_0_0_0 from 11010001111
# Header of 0_0_0_0 self.version=6 self.package_type=4
# Found a packet of type 4
# Searching block 01111
# Added <Packet version=6 package_type=4 15 self.pid='0_0_0_0'> to <Packet version=5 package_type=2  self.pid='0_0_0'>
# Added <Packet version=5 package_type=2  self.pid='0_0_0'> to <Packet version=1 package_type=2  self.pid='0_0'>
# Added <Packet version=1 package_type=2  self.pid='0_0'> to <Packet version=4 package_type=2  self.pid='0'>
# <Packet version=4 package_type=2  self.pid='0'>
# 100010100000000001001010100000000001101010000000000000101111010001111000
# VVVTTTILLLLLLLLLLLVVVTTTILLLLLLLLLLLVVVTTTILLLLLLLLLLLLLLLVVVTTTAAAAA
#                   <Packet version=1 package_type=2  self.pid='0_0'>
#                   001010100000000001101010000000000000101111010001111000
#                   VVVTTTILLLLLLLLLLLVVVTTTILLLLLLLLLLLLLLLVVVTTTAAAAA
#                                     <Packet version=5 package_type=2  self.pid='0_0_0'>
#                                     101010000000000000101111010001111000
#                                     VVVTTTILLLLLLLLLLLLLLLVVVTTTAAAAA
#                                                              <Packet version=6 package_type=4 15 self.pid='0_0_0_0'>
#                                                              11010001111
#                                                              VVVTTTAAAAA
# version_sum=16 expected_version_sum=16
# ----
# Package 3
# Creating packet 0 from 101000000000000101101100100010000000000101100010000000010111110000110110100001101011000110001010001111010100011110000000
# Header of 0 self.version=5 self.package_type=0
# Creating packet 0_0 from 0010001000000000010110001000000001011111000011011010000110101100011000101000111101010001111
# Header of 0_0 self.version=1 self.package_type=0
# Must find 1 subpackets.
# Creating packet 0_0_0 from 0110001000000001011111000011011010000110101100011000101000111101010001111
# Header of 0_0_0 self.version=3 self.package_type=0
# Must find 5 subpackets.
# Creating packet 0_0_0_0 from 1111000011011010000110101100011000101000111101010001111
# Header of 0_0_0_0 self.version=7 self.package_type=4
# Found a packet of type 4
# Searching block 00110
# Added <Packet version=7 package_type=4 6 self.pid='0_0_0_0'> to <Packet version=3 package_type=0  self.pid='0_0_0'>
# Creating packet 0_0_0_1 from 11010000110101100011000101000111101010001111
# Header of 0_0_0_1 self.version=6 self.package_type=4
# Found a packet of type 4
# Searching block 00110
# Added <Packet version=6 package_type=4 6 self.pid='0_0_0_1'> to <Packet version=3 package_type=0  self.pid='0_0_0'>
# Creating packet 0_0_0_2 from 101100011000101000111101010001111
# Header of 0_0_0_2 self.version=5 self.package_type=4
# Found a packet of type 4
# Searching block 01100
# Added <Packet version=5 package_type=4 12 self.pid='0_0_0_2'> to <Packet version=3 package_type=0  self.pid='0_0_0'>
# Creating packet 0_0_0_3 from 0101000111101010001111
# Header of 0_0_0_3 self.version=2 self.package_type=4
# Found a packet of type 4
# Searching block 01111
# Added <Packet version=2 package_type=4 15 self.pid='0_0_0_3'> to <Packet version=3 package_type=0  self.pid='0_0_0'>
# Creating packet 0_0_0_4 from 01010001111
# Header of 0_0_0_4 self.version=2 self.package_type=4
# Found a packet of type 4
# Searching block 01111
# Added <Packet version=2 package_type=4 15 self.pid='0_0_0_4'> to <Packet version=3 package_type=0  self.pid='0_0_0'>
# Added <Packet version=3 package_type=0  self.pid='0_0_0'> to <Packet version=1 package_type=0  self.pid='0_0'>
# Added <Packet version=1 package_type=0  self.pid='0_0'> to <Packet version=5 package_type=0  self.pid='0'>
# <Packet version=5 package_type=0  self.pid='0'>
# 101000000000000101101100100010000000000101100010000000010111110000110110100001101011000110001010001111010100011110000000
# VVVTTTILLLLLLLLLLLLLLLVVVTTTILLLLLLLLLLLVVVTTTILLLLLLLLLLLVVVTTTAAAAAVVVTTTAAAAAVVVTTTAAAAAVVVTTTAAAAAVVVTTTAAAAA
#                              <Packet version=1 package_type=0  self.pid='0_0'>
#                              0010001000000000010110001000000001011111000011011010000110101100011000101000111101010001111
#                              VVVTTTILLLLLLLLLLLVVVTTTILLLLLLLLLLLVVVTTTAAAAAVVVTTTAAAAAVVVTTTAAAAAVVVTTTAAAAAVVVTTTAAAAA
#                                                <Packet version=3 package_type=0  self.pid='0_0_0'>
#                                                0110001000000001011111000011011010000110101100011000101000111101010001111
#                                                VVVTTTILLLLLLLLLLLVVVTTTAAAAAVVVTTTAAAAAVVVTTTAAAAAVVVTTTAAAAAVVVTTTAAAAA
#                                                                  <Packet version=7 package_type=4 6 self.pid='0_0_0_0'>
#                                                                  1111000011011010000110101100011000101000111101010001111
#                                                                  VVVTTTAAAAA
#                                                                             <Packet version=6 package_type=4 6 self.pid='0_0_0_1'>
#                                                                             11010000110101100011000101000111101010001111
#                                                                             VVVTTTAAAAA
#                                                                                        <Packet version=5 package_type=4 12 self.pid='0_0_0_2'>
#                                                                                        101100011000101000111101010001111
#                                                                                        VVVTTTAAAAA
#                                                                                                   <Packet version=2 package_type=4 15 self.pid='0_0_0_3'>
#                                                                                                   0101000111101010001111
#                                                                                                   VVVTTTAAAAA
#                                                                                                              <Packet version=2 package_type=4 15 self.pid='0_0_0_4'>
#                                                                                                              01010001111
#                                                                                                              VVVTTTAAAAA
# version_sum=31 expected_version_sum=31
# ----
# Package 4
# Creating packet 0 from 01100010000000001000000000000000000101100001000101010110001011001000100000000010000100011000111000110100
# Header of 0 self.version=3 self.package_type=0
# Must find 2 subpackets.
# Creating packet 0_0 from 00000000000000000101100001000101010110001011001000100000000010000100011000111000110100
# Header of 0_0 self.version=0 self.package_type=0
# Creating packet 0_0_0 from 0001000101010110001011
# Header of 0_0_0 self.version=0 self.package_type=4
# Found a packet of type 4
# Searching block 01010
# Added <Packet version=0 package_type=4 10 self.pid='0_0_0'> to <Packet version=0 package_type=0  self.pid='0_0'>
# Creating packet 0_0_1 from 10110001011
# Header of 0_0_1 self.version=5 self.package_type=4
# Found a packet of type 4
# Searching block 01011
# Added <Packet version=5 package_type=4 11 self.pid='0_0_1'> to <Packet version=0 package_type=0  self.pid='0_0'>
# Added <Packet version=0 package_type=0  self.pid='0_0'> to <Packet version=3 package_type=0  self.pid='0'>
# Creating packet 0_1 from 001000100000000010000100011000111000110100
# Header of 0_1 self.version=1 self.package_type=0
# Must find 2 subpackets.
# Creating packet 0_1_0 from 000100011000111000110100
# Header of 0_1_0 self.version=0 self.package_type=4
# Found a packet of type 4
# Searching block 01100
# Added <Packet version=0 package_type=4 12 self.pid='0_1_0'> to <Packet version=1 package_type=0  self.pid='0_1'>
# Creating packet 0_1_1 from 0111000110100
# Header of 0_1_1 self.version=3 self.package_type=4
# Found a packet of type 4
# Searching block 01101
# Added <Packet version=3 package_type=4 13 self.pid='0_1_1'> to <Packet version=1 package_type=0  self.pid='0_1'>
# Added <Packet version=1 package_type=0  self.pid='0_1'> to <Packet version=3 package_type=0  self.pid='0'>
# <Packet version=3 package_type=0  self.pid='0'>
# 01100010000000001000000000000000000101100001000101010110001011001000100000000010000100011000111000110100
# VVVTTTILLLLLLLLLLLVVVTTTILLLLLLLLLLLLLLLVVVTTTAAAAAVVVTTTAAAAAVVVTTTILLLLLLLLLLLVVVTTTAAAAAVVVTTTAAAAA
#                   <Packet version=0 package_type=0  self.pid='0_0'>
#                   00000000000000000101100001000101010110001011001000100000000010000100011000111000110100
#                   VVVTTTILLLLLLLLLLLLLLLVVVTTTAAAAAVVVTTTAAAAA
#                                                                                   <Packet version=0 package_type=4 10 self.pid='0_0_0'>
#                                                                                   0001000101010110001011
#                                                                                   VVVTTTAAAAA
#                                                                                              <Packet version=5 package_type=4 11 self.pid='0_0_1'>
#                                                                                              10110001011
#                                                                                              VVVTTTAAAAA
#                                                               <Packet version=1 package_type=0  self.pid='0_1'>
#                                                               001000100000000010000100011000111000110100
#                                                               VVVTTTILLLLLLLLLLLVVVTTTAAAAAVVVTTTAAAAA
#                                                                                 <Packet version=0 package_type=4 12 self.pid='0_1_0'>
#                                                                                 000100011000111000110100
#                                                                                 VVVTTTAAAAA
#                                                                                            <Packet version=3 package_type=4 13 self.pid='0_1_1'>
#                                                                                            0111000110100
#                                                                                            VVVTTTAAAAA
# version_sum=12 expected_version_sum=12
# ----
# Package 5
# Creating packet 0 from 1100000000000001010100000000000000000001011000010001010110100010111000001000000000101111000110000010001101000000
# Header of 0 self.version=6 self.package_type=0
# Creating packet 0_0 from 000000000000000001011000010001010110100010111000001000000000101111000110000010001101
# Header of 0_0 self.version=0 self.package_type=0
# Creating packet 0_0_0 from 0001000101011010001011
# Header of 0_0_0 self.version=0 self.package_type=4
# Found a packet of type 4
# Searching block 01010
# Added <Packet version=0 package_type=4 10 self.pid='0_0_0'> to <Packet version=0 package_type=0  self.pid='0_0'>
# Creating packet 0_0_1 from 11010001011
# Header of 0_0_1 self.version=6 self.package_type=4
# Found a packet of type 4
# Searching block 01011
# Added <Packet version=6 package_type=4 11 self.pid='0_0_1'> to <Packet version=0 package_type=0  self.pid='0_0'>
# Added <Packet version=0 package_type=0  self.pid='0_0'> to <Packet version=6 package_type=0  self.pid='0'>
# Creating packet 0_1 from 1000001000000000101111000110000010001101
# Header of 0_1 self.version=4 self.package_type=0
# Must find 2 subpackets.
# Creating packet 0_1_0 from 1111000110000010001101
# Header of 0_1_0 self.version=7 self.package_type=4
# Found a packet of type 4
# Searching block 01100
# Added <Packet version=7 package_type=4 12 self.pid='0_1_0'> to <Packet version=4 package_type=0  self.pid='0_1'>
# Creating packet 0_1_1 from 00010001101
# Header of 0_1_1 self.version=0 self.package_type=4
# Found a packet of type 4
# Searching block 01101
# Added <Packet version=0 package_type=4 13 self.pid='0_1_1'> to <Packet version=4 package_type=0  self.pid='0_1'>
# Added <Packet version=4 package_type=0  self.pid='0_1'> to <Packet version=6 package_type=0  self.pid='0'>
# <Packet version=6 package_type=0  self.pid='0'>
# 1100000000000001010100000000000000000001011000010001010110100010111000001000000000101111000110000010001101000000
# VVVTTTILLLLLLLLLLLLLLLVVVTTTILLLLLLLLLLLLLLLVVVTTTAAAAAVVVTTTAAAAAVVVTTTILLLLLLLLLLLVVVTTTAAAAAVVVTTTAAAAA
#                             <Packet version=0 package_type=0  self.pid='0_0'>
#                             000000000000000001011000010001010110100010111000001000000000101111000110000010001101
#                             VVVTTTILLLLLLLLLLLLLLLVVVTTTAAAAAVVVTTTAAAAA
#                                                                                           <Packet version=0 package_type=4 10 self.pid='0_0_0'>
#                                                                                           0001000101011010001011
#                                                                                           VVVTTTAAAAA
#                                                                                                      <Packet version=6 package_type=4 11 self.pid='0_0_1'>
#                                                                                                      11010001011
#                                                                                                      VVVTTTAAAAA
#                                                                         <Packet version=4 package_type=0  self.pid='0_1'>
#                                                                         1000001000000000101111000110000010001101
#                                                                         VVVTTTILLLLLLLLLLLVVVTTTAAAAAVVVTTTAAAAA
#                                                                                           <Packet version=7 package_type=4 12 self.pid='0_1_0'>
#                                                                                           1111000110000010001101
#                                                                                           VVVTTTAAAAA
#                                                                                                      <Packet version=0 package_type=4 13 self.pid='0_1_1'>
#                                                                                                      00010001101
#                                                                                                      VVVTTTAAAAA
# version_sum=23 expected_version_sum=23
# ----

# %%
p = Packet(hex_to_bin(real_input))
p.version_sum()
p.compute()
# Out:
# Creating packet 0 from ...
# Header of 0 self.version=4 self.package_type=0
# Creating packet 0_0 from ...
# Header of 0_0 self.version=3 self.package_type=4
# Found a packet of type 4
# Searching block 10010
# Searching block 10111
# Searching block 11100
# Searching block 11100
# Searching block 00011
# Added <Packet version=3 package_type=4 163011 self.pid='0_0'> to <Packet version=4 package_type=0  self.pid='0'>
# Creating packet 0_1 from ...
# Header of 0_1 self.version=4 self.package_type=4
# Found a packet of type 4
# Searching block 10111
# Searching block 00111
# Added <Packet version=4 package_type=4 119 self.pid='0_1'> to <Packet version=4 package_type=0  self.pid='0'>
# Creating packet 0_2 from ...
# Header of 0_2 self.version=5 self.package_type=0
# Creating packet 0_2_0 from 01010011110011111011001100011010110011000011000100111000010110000010101001010111010011110111001010001111
# Header of 0_2_0 self.version=2 self.package_type=4
# Found a packet of type 4
# Searching block 11110
# Searching block 01111
# Added <Packet version=2 package_type=4 239 self.pid='0_2_0'> to <Packet version=5 package_type=0  self.pid='0_2'>
# Creating packet 0_2_1 from 1011001100011010110011000011000100111000010110000010101001010111010011110111001010001111
# Header of 0_2_1 self.version=5 self.package_type=4
# Found a packet of type 4
# Searching block 11000
# Searching block 11010
# Searching block 11001
# Searching block 10000
# Searching block 11000
# Searching block 10011
# Searching block 10000
# Searching block 10110
# Searching block 00001
# Added <Packet version=5 package_type=4 37195624545 self.pid='0_2_1'> to <Packet version=5 package_type=0  self.pid='0_2'>
# Creating packet 0_2_2 from 0101001010111010011110111001010001111
# Header of 0_2_2 self.version=2 self.package_type=4
# Found a packet of type 4
# Searching block 10101
# Searching block 11010
# Searching block 01111
# Added <Packet version=2 package_type=4 1455 self.pid='0_2_2'> to <Packet version=5 package_type=0  self.pid='0_2'>
# Creating packet 0_2_3 from 0111001010001111
# Header of 0_2_3 self.version=3 self.package_type=4
# Found a packet of type 4
# Searching block 10100
# Searching block 01111
# Added <Packet version=3 package_type=4 79 self.pid='0_2_3'> to <Packet version=5 package_type=0  self.pid='0_2'>
# Added <Packet version=5 package_type=0  self.pid='0_2'> to <Packet version=4 package_type=0  self.pid='0'>
# Creating packet 0_3 from ...
# Header of 0_3 self.version=6 self.package_type=0
# Creating packet 0_3_0 from 0111001010111001100111111100010000100000100001001001001011
# Header of 0_3_0 self.version=3 self.package_type=4
# Found a packet of type 4
# Searching block 10101
# Searching block 11001
# Searching block 10011
# Searching block 11111
# Searching block 00010
# Added <Packet version=3 package_type=4 365554 self.pid='0_3_0'> to <Packet version=6 package_type=0  self.pid='0_3'>
# Creating packet 0_3_1 from 000100000100001001001001011
# Header of 0_3_1 self.version=0 self.package_type=4
# Found a packet of type 4
# Searching block 00010
# Added <Packet version=0 package_type=4 2 self.pid='0_3_1'> to <Packet version=6 package_type=0  self.pid='0_3'>
# Creating packet 0_3_2 from 0001001001001011
# Header of 0_3_2 self.version=0 self.package_type=4
# Found a packet of type 4
# Searching block 10010
# Searching block 01011
# Added <Packet version=0 package_type=4 43 self.pid='0_3_2'> to <Packet version=6 package_type=0  self.pid='0_3'>
# Added <Packet version=6 package_type=0  self.pid='0_3'> to <Packet version=4 package_type=0  self.pid='0'>
# Creating packet 0_4 from ...
# Header of 0_4 self.version=7 self.package_type=4
# Found a packet of type 4
# Searching block 10010
# Searching block 10001
# Searching block 01111
# Added <Packet version=7 package_type=4 543 self.pid='0_4'> to <Packet version=4 package_type=0  self.pid='0'>
# Creating packet 0_5 from ...
# Header of 0_5 self.version=3 self.package_type=0
# Must find 3 subpackets.
# Creating packet 0_5_0 from ...
# Header of 0_5_0 self.version=4 self.package_type=1
# Must find 3 subpackets.
# Creating packet 0_5_0_0 from ...
# Header of 0_5_0_0 self.version=5 self.package_type=4
# Found a packet of type 4
# Searching block 00110
# Added <Packet version=5 package_type=4 6 self.pid='0_5_0_0'> to <Packet version=4 package_type=1  self.pid='0_5_0'>
# Creating packet 0_5_0_1 from ...
# Header of 0_5_0_1 self.version=0 self.package_type=4
# Found a packet of type 4
# Searching block 00010
# Added <Packet version=0 package_type=4 2 self.pid='0_5_0_1'> to <Packet version=4 package_type=1  self.pid='0_5_0'>
# Creating packet 0_5_0_2 from ...
# Header of 0_5_0_2 self.version=0 self.package_type=4
# Found a packet of type 4
# Searching block 01101
# Added <Packet version=0 package_type=4 13 self.pid='0_5_0_2'> to <Packet version=4 package_type=1  self.pid='0_5_0'>
# Added <Packet version=4 package_type=1  self.pid='0_5_0'> to <Packet version=3 package_type=0  self.pid='0_5'>
# Creating packet 0_5_1 from ...
# Header of 0_5_1 self.version=0 self.package_type=1
# Creating packet 0_5_1_0 from 101100011000011000001111110001010
# Header of 0_5_1_0 self.version=5 self.package_type=4
# Found a packet of type 4
# Searching block 01100
# Added <Packet version=5 package_type=4 12 self.pid='0_5_1_0'> to <Packet version=0 package_type=1  self.pid='0_5_1'>
# Creating packet 0_5_1_1 from 0011000001111110001010
# Header of 0_5_1_1 self.version=1 self.package_type=4
# Found a packet of type 4
# Searching block 00011
# Added <Packet version=1 package_type=4 3 self.pid='0_5_1_1'> to <Packet version=0 package_type=1  self.pid='0_5_1'>
# Creating packet 0_5_1_2 from 11110001010
# Header of 0_5_1_2 self.version=7 self.package_type=4
# Found a packet of type 4
# Searching block 01010
# Added <Packet version=7 package_type=4 10 self.pid='0_5_1_2'> to <Packet version=0 package_type=1  self.pid='0_5_1'>
# Added <Packet version=0 package_type=1  self.pid='0_5_1'> to <Packet version=3 package_type=0  self.pid='0_5'>
# Creating packet 0_5_2 from ...
# Header of 0_5_2 self.version=4 self.package_type=1
# Creating packet 0_5_2_0 from 111100011011001000101110110001011
# Header of 0_5_2_0 self.version=7 self.package_type=4
# Found a packet of type 4
# Searching block 01101
# Added <Packet version=7 package_type=4 13 self.pid='0_5_2_0'> to <Packet version=4 package_type=1  self.pid='0_5_2'>
# Creating packet 0_5_2_1 from 1001000101110110001011
# Header of 0_5_2_1 self.version=4 self.package_type=4
# Found a packet of type 4
# Searching block 01011
# Added <Packet version=4 package_type=4 11 self.pid='0_5_2_1'> to <Packet version=4 package_type=1  self.pid='0_5_2'>
# Creating packet 0_5_2_2 from 10110001011
# Header of 0_5_2_2 self.version=5 self.package_type=4
# Found a packet of type 4
# Searching block 01011
# Added <Packet version=5 package_type=4 11 self.pid='0_5_2_2'> to <Packet version=4 package_type=1  self.pid='0_5_2'>
# Added <Packet version=4 package_type=1  self.pid='0_5_2'> to <Packet version=3 package_type=0  self.pid='0_5'>
# Added <Packet version=3 package_type=0  self.pid='0_5'> to <Packet version=4 package_type=0  self.pid='0'>
# Creating packet 0_6 from ...
# Header of 0_6 self.version=2 self.package_type=1
# Creating packet 0_6_0 from 011100101010101010110011010001100001001100101111
# Header of 0_6_0 self.version=3 self.package_type=4
# Found a packet of type 4
# Searching block 10101
# Searching block 01010
# Added <Packet version=3 package_type=4 90 self.pid='0_6_0'> to <Packet version=2 package_type=1  self.pid='0_6'>
# Creating packet 0_6_1 from 10110011010001100001001100101111
# Header of 0_6_1 self.version=5 self.package_type=4
# Found a packet of type 4
# Searching block 11010
# Searching block 00110
# Added <Packet version=5 package_type=4 166 self.pid='0_6_1'> to <Packet version=2 package_type=1  self.pid='0_6'>
# Creating packet 0_6_2 from 0001001100101111
# Header of 0_6_2 self.version=0 self.package_type=4
# Found a packet of type 4
# Searching block 11001
# Searching block 01111
# Added <Packet version=0 package_type=4 159 self.pid='0_6_2'> to <Packet version=2 package_type=1  self.pid='0_6'>
# Added <Packet version=2 package_type=1  self.pid='0_6'> to <Packet version=4 package_type=0  self.pid='0'>
# Creating packet 0_7 from ...
# Header of 0_7 self.version=2 self.package_type=4
# Found a packet of type 4
# Searching block 01010
# Added <Packet version=2 package_type=4 10 self.pid='0_7'> to <Packet version=4 package_type=0  self.pid='0'>
# Creating packet 0_8 from ...
# Header of 0_8 self.version=7 self.package_type=1
# Must find 1 subpackets.
# Creating packet 0_8_0 from ...
# Header of 0_8_0 self.version=4 self.package_type=4
# Found a packet of type 4
# Searching block 11010
# Searching block 00101
# Added <Packet version=4 package_type=4 165 self.pid='0_8_0'> to <Packet version=7 package_type=1  self.pid='0_8'>
# Added <Packet version=7 package_type=1  self.pid='0_8'> to <Packet version=4 package_type=0  self.pid='0'>
# Creating packet 0_9 from ...
# Header of 0_9 self.version=7 self.package_type=1
# Must find 2 subpackets.
# Creating packet 0_9_0 from ...
# Header of 0_9_0 self.version=4 self.package_type=4
# Found a packet of type 4
# Searching block 01011
# Added <Packet version=4 package_type=4 11 self.pid='0_9_0'> to <Packet version=7 package_type=1  self.pid='0_9'>
# Creating packet 0_9_1 from ...
# Header of 0_9_1 self.version=4 self.package_type=6
# Must find 2 subpackets.
# Creating packet 0_9_1_0 from ...
# Header of 0_9_1_0 self.version=6 self.package_type=0
# Must find 3 subpackets.
# Creating packet 0_9_1_0_0 from ...
# Header of 0_9_1_0_0 self.version=0 self.package_type=4
# Found a packet of type 4
# Searching block 01011
# Added <Packet version=0 package_type=4 11 self.pid='0_9_1_0_0'> to <Packet version=6 package_type=0  self.pid='0_9_1_0'>
# Creating packet 0_9_1_0_1 from ...
# Header of 0_9_1_0_1 self.version=6 self.package_type=4
# Found a packet of type 4
# Searching block 00011
# Added <Packet version=6 package_type=4 3 self.pid='0_9_1_0_1'> to <Packet version=6 package_type=0  self.pid='0_9_1_0'>
# Creating packet 0_9_1_0_2 from ...
# Header of 0_9_1_0_2 self.version=7 self.package_type=4
# Found a packet of type 4
# Searching block 01101
# Added <Packet version=7 package_type=4 13 self.pid='0_9_1_0_2'> to <Packet version=6 package_type=0  self.pid='0_9_1_0'>
# Added <Packet version=6 package_type=0  self.pid='0_9_1_0'> to <Packet version=4 package_type=6  self.pid='0_9_1'>
# Creating packet 0_9_1_1 from ...
# Header of 0_9_1_1 self.version=6 self.package_type=0
# Must find 3 subpackets.
# Creating packet 0_9_1_1_0 from ...
# Header of 0_9_1_1_0 self.version=6 self.package_type=4
# Found a packet of type 4
# Searching block 00010
# Added <Packet version=6 package_type=4 2 self.pid='0_9_1_1_0'> to <Packet version=6 package_type=0  self.pid='0_9_1_1'>
# Creating packet 0_9_1_1_1 from ...
# Header of 0_9_1_1_1 self.version=1 self.package_type=4
# Found a packet of type 4
# Searching block 01101
# Added <Packet version=1 package_type=4 13 self.pid='0_9_1_1_1'> to <Packet version=6 package_type=0  self.pid='0_9_1_1'>
# Creating packet 0_9_1_1_2 from ...
# Header of 0_9_1_1_2 self.version=1 self.package_type=4
# Found a packet of type 4
# Searching block 01011
# Added <Packet version=1 package_type=4 11 self.pid='0_9_1_1_2'> to <Packet version=6 package_type=0  self.pid='0_9_1_1'>
# Added <Packet version=6 package_type=0  self.pid='0_9_1_1'> to <Packet version=4 package_type=6  self.pid='0_9_1'>
# Added <Packet version=4 package_type=6  self.pid='0_9_1'> to <Packet version=7 package_type=1  self.pid='0_9'>
# Added <Packet version=7 package_type=1  self.pid='0_9'> to <Packet version=4 package_type=0  self.pid='0'>
# Creating packet 0_10 from ...
# Header of 0_10 self.version=5 self.package_type=2
# Must find 1 subpackets.
# Creating packet 0_10_0 from ...
# Header of 0_10_0 self.version=6 self.package_type=4
# Found a packet of type 4
# Searching block 01001
# Added <Packet version=6 package_type=4 9 self.pid='0_10_0'> to <Packet version=5 package_type=2  self.pid='0_10'>
# Added <Packet version=5 package_type=2  self.pid='0_10'> to <Packet version=4 package_type=0  self.pid='0'>
# Creating packet 0_11 from ...
# Header of 0_11 self.version=3 self.package_type=3
# Creating packet 0_11_0 from ...
# Header of 0_11_0 self.version=5 self.package_type=1
# Must find 1 subpackets.
# Creating packet 0_11_0_0 from ...
# Header of 0_11_0_0 self.version=3 self.package_type=3
# Must find 1 subpackets.
# Creating packet 0_11_0_0_0 from 
# Header of 0_11_0_0_0 self.version=7 self.package_type=1
# Creating packet 0_11_0_0_0_0 from 
# Header of 0_11_0_0_0_0 self.version=5 self.package_type=1
# Must find 1 subpackets.
# Creating packet 0_11_0_0_0_0_0 from 
# Header of 0_11_0_0_0_0_0 self.version=3 self.package_type=1
# Creating packet 0_11_0_0_0_0_0_0 from 
# Header of 0_11_0_0_0_0_0_0 self.version=7 self.package_type=3
# Must find 1 subpackets.
# Creating packet 0_11_0_0_0_0_0_0_0 from 
# Header of 0_11_0_0_0_0_0_0_0 self.version=4 self.package_type=2
# Must find 1 subpackets.
# Creating packet 0_11_0_0_0_0_0_0_0_0 from 
# Header of 0_11_0_0_0_0_0_0_0_0 self.version=7 self.package_type=2
# Creating packet 0_11_0_0_0_0_0_0_0_0_0 from 
# Header of 0_11_0_0_0_0_0_0_0_0_0 self.version=5 self.package_type=0
# Creating packet 0_11_0_0_0_0_0_0_0_0_0_0 from 1010000000000011011011000010100000000001000001000000001011001101001110000000000110100110000000000101001100000000011110010010100000000001100011001010100000000001010001000000000011101111001010000000000111010011010110011111111110100111001100101
# Header of 0_11_0_0_0_0_0_0_0_0_0_0 self.version=5 self.package_type=0
# Creating packet 0_11_0_0_0_0_0_0_0_0_0_0_0 from 000010100000000001000001000000001011001101001110000000000110100110000000000101001100000000011110010010100000000001100011001010100000000001010001000000000011101111001010000000000111010011010110011111111110100111001100101
# Header of 0_11_0_0_0_0_0_0_0_0_0_0_0 self.version=0 self.package_type=2
# Must find 1 subpackets.
# Creating packet 0_11_0_0_0_0_0_0_0_0_0_0_0_0 from 000001000000001011001101001110000000000110100110000000000101001100000000011110010010100000000001100011001010100000000001010001000000000011101111001010000000000111010011010110011111111110100111001100101
# Header of 0_11_0_0_0_0_0_0_0_0_0_0_0_0 self.version=0 self.package_type=1
# Creating packet 0_11_0_0_0_0_0_0_0_0_0_0_0_0_0 from 01001110000000000110100110000000000101001100000000011110010010100000000001100011001010100000000001010001000000000011101111001010000000000111010011010110011111111110100111001100101
# Header of 0_11_0_0_0_0_0_0_0_0_0_0_0_0_0 self.version=2 self.package_type=3
# Must find 1 subpackets.
# Creating packet 0_11_0_0_0_0_0_0_0_0_0_0_0_0_0_0 from 10100110000000000101001100000000011110010010100000000001100011001010100000000001010001000000000011101111001010000000000111010011010110011111111110100111001100101
# Header of 0_11_0_0_0_0_0_0_0_0_0_0_0_0_0_0 self.version=5 self.package_type=1
# Must find 1 subpackets.
# Creating packet 0_11_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0 from 01001100000000011110010010100000000001100011001010100000000001010001000000000011101111001010000000000111010011010110011111111110100111001100101
# Header of 0_11_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0 self.version=2 self.package_type=3
# Creating packet 0_11_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0 from 0010100000000001100011001010100000000001010001000000000011101111001010000000000111010011010110011111111110100111001100101
# Header of 0_11_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0 self.version=1 self.package_type=2
# Creating packet 0_11_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0 from 001010100000000001010001000000000011101111001010000000000111010011010110011111111110100111001100101
# Header of 0_11_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0 self.version=1 self.package_type=2
# Must find 1 subpackets.
# Creating packet 0_11_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0 from 010001000000000011101111001010000000000111010011010110011111111110100111001100101
# Header of 0_11_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0 self.version=2 self.package_type=1
# Creating packet 0_11_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0 from 11001010000000000111010011010110011111111110100111001100101
# Header of 0_11_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0 self.version=6 self.package_type=2
# Must find 1 subpackets.
# Creating packet 0_11_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0 from 11010011010110011111111110100111001100101
# Header of 0_11_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0 self.version=6 self.package_type=4
# Found a packet of type 4
# Searching block 11010
# Searching block 11001
# Searching block 11111
# Searching block 11110
# Searching block 10011
# Searching block 10011
# Searching block 00101
# Added <Packet version=6 package_type=4 178250549 self.pid='0_11_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0'> to <Packet version=6 package_type=2  self.pid='0_11_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0'>
# Added <Packet version=6 package_type=2  self.pid='0_11_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0'> to <Packet version=2 package_type=1  self.pid='0_11_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0'>
# Added <Packet version=2 package_type=1  self.pid='0_11_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0'> to <Packet version=1 package_type=2  self.pid='0_11_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0'>
# Added <Packet version=1 package_type=2  self.pid='0_11_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0'> to <Packet version=1 package_type=2  self.pid='0_11_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0'>
# Added <Packet version=1 package_type=2  self.pid='0_11_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0'> to <Packet version=2 package_type=3  self.pid='0_11_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0'>
# Added <Packet version=2 package_type=3  self.pid='0_11_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0'> to <Packet version=5 package_type=1  self.pid='0_11_0_0_0_0_0_0_0_0_0_0_0_0_0_0'>
# Added <Packet version=5 package_type=1  self.pid='0_11_0_0_0_0_0_0_0_0_0_0_0_0_0_0'> to <Packet version=2 package_type=3  self.pid='0_11_0_0_0_0_0_0_0_0_0_0_0_0_0'>
# Added <Packet version=2 package_type=3  self.pid='0_11_0_0_0_0_0_0_0_0_0_0_0_0_0'> to <Packet version=0 package_type=1  self.pid='0_11_0_0_0_0_0_0_0_0_0_0_0_0'>
# Added <Packet version=0 package_type=1  self.pid='0_11_0_0_0_0_0_0_0_0_0_0_0_0'> to <Packet version=0 package_type=2  self.pid='0_11_0_0_0_0_0_0_0_0_0_0_0'>
# Added <Packet version=0 package_type=2  self.pid='0_11_0_0_0_0_0_0_0_0_0_0_0'> to <Packet version=5 package_type=0  self.pid='0_11_0_0_0_0_0_0_0_0_0_0'>
# Added <Packet version=5 package_type=0  self.pid='0_11_0_0_0_0_0_0_0_0_0_0'> to <Packet version=5 package_type=0  self.pid='0_11_0_0_0_0_0_0_0_0_0'>
# Added <Packet version=5 package_type=0  self.pid='0_11_0_0_0_0_0_0_0_0_0'> to <Packet version=7 package_type=2  self.pid='0_11_0_0_0_0_0_0_0_0'>
# Added <Packet version=7 package_type=2  self.pid='0_11_0_0_0_0_0_0_0_0'> to <Packet version=4 package_type=2  self.pid='0_11_0_0_0_0_0_0_0'>
# Added <Packet version=4 package_type=2  self.pid='0_11_0_0_0_0_0_0_0'> to <Packet version=7 package_type=3  self.pid='0_11_0_0_0_0_0_0'>
# Added <Packet version=7 package_type=3  self.pid='0_11_0_0_0_0_0_0'> to <Packet version=3 package_type=1  self.pid='0_11_0_0_0_0_0'>
# Added <Packet version=3 package_type=1  self.pid='0_11_0_0_0_0_0'> to <Packet version=5 package_type=1  self.pid='0_11_0_0_0_0'>
# Added <Packet version=5 package_type=1  self.pid='0_11_0_0_0_0'> to <Packet version=7 package_type=1  self.pid='0_11_0_0_0'>
# Added <Packet version=7 package_type=1  self.pid='0_11_0_0_0'> to <Packet version=3 package_type=3  self.pid='0_11_0_0'>
# Added <Packet version=3 package_type=3  self.pid='0_11_0_0'> to <Packet version=5 package_type=1  self.pid='0_11_0'>
# Added <Packet version=5 package_type=1  self.pid='0_11_0'> to <Packet version=3 package_type=3  self.pid='0_11'>
# Added <Packet version=3 package_type=3  self.pid='0_11'> to <Packet version=4 package_type=0  self.pid='0'>
# Creating packet 0_12 from ...
# Header of 0_12 self.version=2 self.package_type=0
# Creating packet 0_12_0 from 001100010001111001010110111100111110010010000011111000010110010010110111101011111011010011001001010101100
# Header of 0_12_0 self.version=1 self.package_type=4
# Found a packet of type 4
# Searching block 01000
# Added <Packet version=1 package_type=4 8 self.pid='0_12_0'> to <Packet version=2 package_type=0  self.pid='0_12'>
# Creating packet 0_12_1 from 1111001010110111100111110010010000011111000010110010010110111101011111011010011001001010101100
# Header of 0_12_1 self.version=7 self.package_type=4
# Found a packet of type 4
# Searching block 10101
# Searching block 10111
# Searching block 10011
# Searching block 11100
# Searching block 10010
# Searching block 00001
# Added <Packet version=7 package_type=4 5717025 self.pid='0_12_1'> to <Packet version=2 package_type=0  self.pid='0_12'>
# Creating packet 0_12_2 from 1111000010110010010110111101011111011010011001001010101100
# Header of 0_12_2 self.version=7 self.package_type=4
# Found a packet of type 4
# Searching block 00101
# Added <Packet version=7 package_type=4 5 self.pid='0_12_2'> to <Packet version=2 package_type=0  self.pid='0_12'>
# Creating packet 0_12_3 from 10010010110111101011111011010011001001010101100
# Header of 0_12_3 self.version=4 self.package_type=4
# Found a packet of type 4
# Searching block 10110
# Searching block 11110
# Searching block 10111
# Searching block 11011
# Searching block 01001
# Added <Packet version=4 package_type=4 452537 self.pid='0_12_3'> to <Packet version=2 package_type=0  self.pid='0_12'>
# Creating packet 0_12_4 from 1001001010101100
# Header of 0_12_4 self.version=4 self.package_type=4
# Found a packet of type 4
# Searching block 10101
# Searching block 01100
# Added <Packet version=4 package_type=4 92 self.pid='0_12_4'> to <Packet version=2 package_type=0  self.pid='0_12'>
# Added <Packet version=2 package_type=0  self.pid='0_12'> to <Packet version=4 package_type=0  self.pid='0'>
# Creating packet 0_13 from ...
# Header of 0_13 self.version=2 self.package_type=1
# Creating packet 0_13_0 from 1111110000000000100000001100101100111010010010110011101001001101010010101011111001111
# Header of 0_13_0 self.version=7 self.package_type=7
# Creating packet 0_13_0_0 from 00110010110011101001001011001110
# Header of 0_13_0_0 self.version=1 self.package_type=4
# Found a packet of type 4
# Searching block 10110
# Searching block 01110
# Added <Packet version=1 package_type=4 110 self.pid='0_13_0_0'> to <Packet version=7 package_type=7  self.pid='0_13_0'>
# Creating packet 0_13_0_1 from 1001001011001110
# Header of 0_13_0_1 self.version=4 self.package_type=4
# Found a packet of type 4
# Searching block 10110
# Searching block 01110
# Added <Packet version=4 package_type=4 110 self.pid='0_13_0_1'> to <Packet version=7 package_type=7  self.pid='0_13_0'>
# Added <Packet version=7 package_type=7  self.pid='0_13_0'> to <Packet version=2 package_type=1  self.pid='0_13'>
# Creating packet 0_13_1 from 1001001101010010101011111001111
# Header of 0_13_1 self.version=4 self.package_type=4
# Found a packet of type 4
# Searching block 11010
# Searching block 10010
# Searching block 10101
# Searching block 11110
# Searching block 01111
# Added <Packet version=4 package_type=4 665071 self.pid='0_13_1'> to <Packet version=2 package_type=1  self.pid='0_13'>
# Added <Packet version=2 package_type=1  self.pid='0_13'> to <Packet version=4 package_type=0  self.pid='0'>
# Creating packet 0_14 from ...
# Header of 0_14 self.version=5 self.package_type=1
# Must find 2 subpackets.
# Creating packet 0_14_0 from ...
# Header of 0_14_0 self.version=1 self.package_type=4
# Found a packet of type 4
# Searching block 11011
# Searching block 11011
# Searching block 11011
# Searching block 10100
# Searching block 10011
# Searching block 11100
# Searching block 11011
# Searching block 11100
# Searching block 11100
# Searching block 01010
# Added <Packet version=1 package_type=4 806182763722 self.pid='0_14_0'> to <Packet version=5 package_type=1  self.pid='0_14'>
# Creating packet 0_14_1 from ...
# Header of 0_14_1 self.version=5 self.package_type=6
# Must find 2 subpackets.
# Creating packet 0_14_1_0 from ...
# Header of 0_14_1_0 self.version=3 self.package_type=4
# Found a packet of type 4
# Searching block 11001
# Searching block 10101
# Searching block 01000
# Added <Packet version=3 package_type=4 2392 self.pid='0_14_1_0'> to <Packet version=5 package_type=6  self.pid='0_14_1'>
# Creating packet 0_14_1_1 from ...
# Header of 0_14_1_1 self.version=5 self.package_type=4
# Found a packet of type 4
# Searching block 11001
# Searching block 10101
# Searching block 01000
# Added <Packet version=5 package_type=4 2392 self.pid='0_14_1_1'> to <Packet version=5 package_type=6  self.pid='0_14_1'>
# Added <Packet version=5 package_type=6  self.pid='0_14_1'> to <Packet version=5 package_type=1  self.pid='0_14'>
# Added <Packet version=5 package_type=1  self.pid='0_14'> to <Packet version=4 package_type=0  self.pid='0'>
# Creating packet 0_15 from ...
# Header of 0_15 self.version=4 self.package_type=2
# Must find 4 subpackets.
# Creating packet 0_15_0 from ...
# Header of 0_15_0 self.version=7 self.package_type=4
# Found a packet of type 4
# Searching block 00111
# Added <Packet version=7 package_type=4 7 self.pid='0_15_0'> to <Packet version=4 package_type=2  self.pid='0_15'>
# Creating packet 0_15_1 from ...
# Header of 0_15_1 self.version=1 self.package_type=4
# Found a packet of type 4
# Searching block 11001
# Searching block 11010
# Searching block 10111
# Searching block 11101
# Searching block 00101
# Added <Packet version=1 package_type=4 632789 self.pid='0_15_1'> to <Packet version=4 package_type=2  self.pid='0_15'>
# Creating packet 0_15_2 from ...
# Header of 0_15_2 self.version=1 self.package_type=4
# Found a packet of type 4
# Searching block 11010
# Searching block 10100
# Searching block 10011
# Searching block 00000
# Added <Packet version=1 package_type=4 42032 self.pid='0_15_2'> to <Packet version=4 package_type=2  self.pid='0_15'>
# Creating packet 0_15_3 from ...
# Header of 0_15_3 self.version=1 self.package_type=4
# Found a packet of type 4
# Searching block 11010
# Searching block 10101
# Searching block 10001
# Searching block 10111
# Searching block 10101
# Searching block 00110
# Added <Packet version=1 package_type=4 10819414 self.pid='0_15_3'> to <Packet version=4 package_type=2  self.pid='0_15'>
# Added <Packet version=4 package_type=2  self.pid='0_15'> to <Packet version=4 package_type=0  self.pid='0'>
# Creating packet 0_16 from ...
# Header of 0_16 self.version=1 self.package_type=3
# Creating packet 0_16_0 from 1001001110000010001100100111110111000011001011001111010101101111111001000010100110011110111010001110101001010110001111001011100111
# Header of 0_16_0 self.version=4 self.package_type=4
# Found a packet of type 4
# Searching block 11100
# Searching block 00010
# Added <Packet version=4 package_type=4 194 self.pid='0_16_0'> to <Packet version=1 package_type=3  self.pid='0_16'>
# Creating packet 0_16_1 from 001100100111110111000011001011001111010101101111111001000010100110011110111010001110101001010110001111001011100111
# Header of 0_16_1 self.version=1 self.package_type=4
# Found a packet of type 4
# Searching block 10011
# Searching block 11101
# Searching block 11000
# Searching block 01100
# Added <Packet version=1 package_type=4 15756 self.pid='0_16_1'> to <Packet version=1 package_type=3  self.pid='0_16'>
# Creating packet 0_16_2 from 1011001111010101101111111001000010100110011110111010001110101001010110001111001011100111
# Header of 0_16_2 self.version=5 self.package_type=4
# Found a packet of type 4
# Searching block 11110
# Searching block 10101
# Searching block 10111
# Searching block 11110
# Searching block 01000
# Added <Packet version=5 package_type=4 940008 self.pid='0_16_2'> to <Packet version=1 package_type=3  self.pid='0_16'>
# Creating packet 0_16_3 from 010100110011110111010001110101001010110001111001011100111
# Header of 0_16_3 self.version=2 self.package_type=4
# Found a packet of type 4
# Searching block 11001
# Searching block 11101
# Searching block 11010
# Searching block 00111
# Added <Packet version=2 package_type=4 40359 self.pid='0_16_3'> to <Packet version=1 package_type=3  self.pid='0_16'>
# Creating packet 0_16_4 from 0101001010110001111001011100111
# Header of 0_16_4 self.version=2 self.package_type=4
# Found a packet of type 4
# Searching block 10101
# Searching block 10001
# Searching block 11100
# Searching block 10111
# Searching block 00111
# Added <Packet version=2 package_type=4 334967 self.pid='0_16_4'> to <Packet version=1 package_type=3  self.pid='0_16'>
# Added <Packet version=1 package_type=3  self.pid='0_16'> to <Packet version=4 package_type=0  self.pid='0'>
# Creating packet 0_17 from ...
# Header of 0_17 self.version=3 self.package_type=3
# Must find 4 subpackets.
# Creating packet 0_17_0 from ...
# Header of 0_17_0 self.version=2 self.package_type=4
# Found a packet of type 4
# Searching block 10111
# Searching block 10000
# Searching block 01110
# Added <Packet version=2 package_type=4 1806 self.pid='0_17_0'> to <Packet version=3 package_type=3  self.pid='0_17'>
# Creating packet 0_17_1 from ...
# Header of 0_17_1 self.version=1 self.package_type=4
# Found a packet of type 4
# Searching block 01100
# Added <Packet version=1 package_type=4 12 self.pid='0_17_1'> to <Packet version=3 package_type=3  self.pid='0_17'>
# Creating packet 0_17_2 from ...
# Header of 0_17_2 self.version=4 self.package_type=4
# Found a packet of type 4
# Searching block 11111
# Searching block 01101
# Added <Packet version=4 package_type=4 253 self.pid='0_17_2'> to <Packet version=3 package_type=3  self.pid='0_17'>
# Creating packet 0_17_3 from ...
# Header of 0_17_3 self.version=7 self.package_type=4
# Found a packet of type 4
# Searching block 10001
# Searching block 00111
# Added <Packet version=7 package_type=4 23 self.pid='0_17_3'> to <Packet version=3 package_type=3  self.pid='0_17'>
# Added <Packet version=3 package_type=3  self.pid='0_17'> to <Packet version=4 package_type=0  self.pid='0'>
# Creating packet 0_18 from ...
# Header of 0_18 self.version=0 self.package_type=1
# Must find 2 subpackets.
# Creating packet 0_18_0 from ...
# Header of 0_18_0 self.version=0 self.package_type=4
# Found a packet of type 4
# Searching block 10010
# Searching block 11100
# Searching block 11100
# Searching block 00110
# Added <Packet version=0 package_type=4 11462 self.pid='0_18_0'> to <Packet version=0 package_type=1  self.pid='0_18'>
# Creating packet 0_18_1 from ...
# Header of 0_18_1 self.version=4 self.package_type=5
# Must find 2 subpackets.
# Creating packet 0_18_1_0 from ...
# Header of 0_18_1_0 self.version=2 self.package_type=4
# Found a packet of type 4
# Searching block 11000
# Searching block 11110
# Searching block 01100
# Added <Packet version=2 package_type=4 2284 self.pid='0_18_1_0'> to <Packet version=4 package_type=5  self.pid='0_18_1'>
# Creating packet 0_18_1_1 from ...
# Header of 0_18_1_1 self.version=7 self.package_type=4
# Found a packet of type 4
# Searching block 10001
# Searching block 11000
# Searching block 10100
# Searching block 10101
# Searching block 10101
# Searching block 10111
# Searching block 00010
# Added <Packet version=7 package_type=4 25449842 self.pid='0_18_1_1'> to <Packet version=4 package_type=5  self.pid='0_18_1'>
# Added <Packet version=4 package_type=5  self.pid='0_18_1'> to <Packet version=0 package_type=1  self.pid='0_18'>
# Added <Packet version=0 package_type=1  self.pid='0_18'> to <Packet version=4 package_type=0  self.pid='0'>
# Creating packet 0_19 from ...
# Header of 0_19 self.version=5 self.package_type=1
# Creating packet 0_19_0 from 01010010110100111111111000110011100101110010111100000000010110000100000000011010100000110011000111011010001001111000100000000011010100010000001000111101110001100
# Header of 0_19_0 self.version=2 self.package_type=4
# Found a packet of type 4
# Searching block 10110
# Searching block 10011
# Searching block 11111
# Searching block 11000
# Searching block 11001
# Searching block 11001
# Searching block 01110
# Added <Packet version=2 package_type=4 104827294 self.pid='0_19_0'> to <Packet version=5 package_type=1  self.pid='0_19'>
# Creating packet 0_19_1 from 010111100000000010110000100000000011010100000110011000111011010001001111000100000000011010100010000001000111101110001100
# Header of 0_19_1 self.version=2 self.package_type=7
# Must find 2 subpackets.
# Creating packet 0_19_1_0 from 110000100000000011010100000110011000111011010001001111000100000000011010100010000001000111101110001100
# Header of 0_19_1_0 self.version=6 self.package_type=0
# Must find 3 subpackets.
# Creating packet 0_19_1_0_0 from 010100000110011000111011010001001111000100000000011010100010000001000111101110001100
# Header of 0_19_1_0_0 self.version=2 self.package_type=4
# Found a packet of type 4
# Searching block 00011
# Added <Packet version=2 package_type=4 3 self.pid='0_19_1_0_0'> to <Packet version=6 package_type=0  self.pid='0_19_1_0'>
# Creating packet 0_19_1_0_1 from 0011000111011010001001111000100000000011010100010000001000111101110001100
# Header of 0_19_1_0_1 self.version=1 self.package_type=4
# Found a packet of type 4
# Searching block 01110
# Added <Packet version=1 package_type=4 14 self.pid='0_19_1_0_1'> to <Packet version=6 package_type=0  self.pid='0_19_1_0'>
# Creating packet 0_19_1_0_2 from 11010001001111000100000000011010100010000001000111101110001100
# Header of 0_19_1_0_2 self.version=6 self.package_type=4
# Found a packet of type 4
# Searching block 01001
# Added <Packet version=6 package_type=4 9 self.pid='0_19_1_0_2'> to <Packet version=6 package_type=0  self.pid='0_19_1_0'>
# Added <Packet version=6 package_type=0  self.pid='0_19_1_0'> to <Packet version=2 package_type=7  self.pid='0_19_1'>
# Creating packet 0_19_1_1 from 111000100000000011010100010000001000111101110001100
# Header of 0_19_1_1 self.version=7 self.package_type=0
# Must find 3 subpackets.
# Creating packet 0_19_1_1_0 from 010100010000001000111101110001100
# Header of 0_19_1_1_0 self.version=2 self.package_type=4
# Found a packet of type 4
# Searching block 01000
# Added <Packet version=2 package_type=4 8 self.pid='0_19_1_1_0'> to <Packet version=7 package_type=0  self.pid='0_19_1_1'>
# Creating packet 0_19_1_1_1 from 0001000111101110001100
# Header of 0_19_1_1_1 self.version=0 self.package_type=4
# Found a packet of type 4
# Searching block 01111
# Added <Packet version=0 package_type=4 15 self.pid='0_19_1_1_1'> to <Packet version=7 package_type=0  self.pid='0_19_1_1'>
# Creating packet 0_19_1_1_2 from 01110001100
# Header of 0_19_1_1_2 self.version=3 self.package_type=4
# Found a packet of type 4
# Searching block 01100
# Added <Packet version=3 package_type=4 12 self.pid='0_19_1_1_2'> to <Packet version=7 package_type=0  self.pid='0_19_1_1'>
# Added <Packet version=7 package_type=0  self.pid='0_19_1_1'> to <Packet version=2 package_type=7  self.pid='0_19_1'>
# Added <Packet version=2 package_type=7  self.pid='0_19_1'> to <Packet version=5 package_type=1  self.pid='0_19'>
# Added <Packet version=5 package_type=1  self.pid='0_19'> to <Packet version=4 package_type=0  self.pid='0'>
# Creating packet 0_20 from ...
# Header of 0_20 self.version=2 self.package_type=4
# Found a packet of type 4
# Searching block 01110
# Added <Packet version=2 package_type=4 14 self.pid='0_20'> to <Packet version=4 package_type=0  self.pid='0'>
# Creating packet 0_21 from ...
# Header of 0_21 self.version=3 self.package_type=1
# Creating packet 0_21_0 from 11011000000000001010101001001010011100101010001111110011000010001101001111100011
# Header of 0_21_0 self.version=6 self.package_type=6
# Creating packet 0_21_0_0 from 100100101001110010101000111111001100001000
# Header of 0_21_0_0 self.version=4 self.package_type=4
# Found a packet of type 4
# Searching block 10100
# Searching block 11100
# Searching block 10101
# Searching block 00011
# Added <Packet version=4 package_type=4 19539 self.pid='0_21_0_0'> to <Packet version=6 package_type=6  self.pid='0_21_0'>
# Creating packet 0_21_0_1 from 1111001100001000
# Header of 0_21_0_1 self.version=7 self.package_type=4
# Found a packet of type 4
# Searching block 11000
# Searching block 01000
# Added <Packet version=7 package_type=4 136 self.pid='0_21_0_1'> to <Packet version=6 package_type=6  self.pid='0_21_0'>
# Added <Packet version=6 package_type=6  self.pid='0_21_0'> to <Packet version=3 package_type=1  self.pid='0_21'>
# Creating packet 0_21_1 from 1101001111100011
# Header of 0_21_1 self.version=6 self.package_type=4
# Found a packet of type 4
# Searching block 11111
# Searching block 00011
# Added <Packet version=6 package_type=4 243 self.pid='0_21_1'> to <Packet version=3 package_type=1  self.pid='0_21'>
# Added <Packet version=3 package_type=1  self.pid='0_21'> to <Packet version=4 package_type=0  self.pid='0'>
# Creating packet 0_22 from ...
# Header of 0_22 self.version=5 self.package_type=4
# Found a packet of type 4
# Searching block 00110
# Added <Packet version=5 package_type=4 6 self.pid='0_22'> to <Packet version=4 package_type=0  self.pid='0'>
# Creating packet 0_23 from ...
# Header of 0_23 self.version=6 self.package_type=4
# Found a packet of type 4
# Searching block 11110
# Searching block 00001
# Added <Packet version=6 package_type=4 225 self.pid='0_23'> to <Packet version=4 package_type=0  self.pid='0'>
# Creating packet 0_24 from ...
# Header of 0_24 self.version=7 self.package_type=1
# Must find 3 subpackets.
# Creating packet 0_24_0 from ...
# Header of 0_24_0 self.version=7 self.package_type=0
# Creating packet 0_24_0_0 from 000100011000101000010010010000100
# Header of 0_24_0_0 self.version=0 self.package_type=4
# Found a packet of type 4
# Searching block 01100
# Added <Packet version=0 package_type=4 12 self.pid='0_24_0_0'> to <Packet version=7 package_type=0  self.pid='0_24_0'>
# Creating packet 0_24_0_1 from 0101000010010010000100
# Header of 0_24_0_1 self.version=2 self.package_type=4
# Found a packet of type 4
# Searching block 00100
# Added <Packet version=2 package_type=4 4 self.pid='0_24_0_1'> to <Packet version=7 package_type=0  self.pid='0_24_0'>
# Creating packet 0_24_0_2 from 10010000100
# Header of 0_24_0_2 self.version=4 self.package_type=4
# Found a packet of type 4
# Searching block 00100
# Added <Packet version=4 package_type=4 4 self.pid='0_24_0_2'> to <Packet version=7 package_type=0  self.pid='0_24_0'>
# Added <Packet version=7 package_type=0  self.pid='0_24_0'> to <Packet version=7 package_type=1  self.pid='0_24'>
# Creating packet 0_24_1 from ...
# Header of 0_24_1 self.version=6 self.package_type=0
# Must find 3 subpackets.
# Creating packet 0_24_1_0 from ...
# Header of 0_24_1_0 self.version=3 self.package_type=4
# Found a packet of type 4
# Searching block 01000
# Added <Packet version=3 package_type=4 8 self.pid='0_24_1_0'> to <Packet version=6 package_type=0  self.pid='0_24_1'>
# Creating packet 0_24_1_1 from ...
# Header of 0_24_1_1 self.version=7 self.package_type=4
# Found a packet of type 4
# Searching block 01111
# Added <Packet version=7 package_type=4 15 self.pid='0_24_1_1'> to <Packet version=6 package_type=0  self.pid='0_24_1'>
# Creating packet 0_24_1_2 from ...
# Header of 0_24_1_2 self.version=6 self.package_type=4
# Found a packet of type 4
# Searching block 00010
# Added <Packet version=6 package_type=4 2 self.pid='0_24_1_2'> to <Packet version=6 package_type=0  self.pid='0_24_1'>
# Added <Packet version=6 package_type=0  self.pid='0_24_1'> to <Packet version=7 package_type=1  self.pid='0_24'>
# Creating packet 0_24_2 from ...
# Header of 0_24_2 self.version=3 self.package_type=0
# Creating packet 0_24_2_0 from 100100000110101000110101010001111
# Header of 0_24_2_0 self.version=4 self.package_type=4
# Found a packet of type 4
# Searching block 00011
# Added <Packet version=4 package_type=4 3 self.pid='0_24_2_0'> to <Packet version=3 package_type=0  self.pid='0_24_2'>
# Creating packet 0_24_2_1 from 0101000110101010001111
# Header of 0_24_2_1 self.version=2 self.package_type=4
# Found a packet of type 4
# Searching block 01101
# Added <Packet version=2 package_type=4 13 self.pid='0_24_2_1'> to <Packet version=3 package_type=0  self.pid='0_24_2'>
# Creating packet 0_24_2_2 from 01010001111
# Header of 0_24_2_2 self.version=2 self.package_type=4
# Found a packet of type 4
# Searching block 01111
# Added <Packet version=2 package_type=4 15 self.pid='0_24_2_2'> to <Packet version=3 package_type=0  self.pid='0_24_2'>
# Added <Packet version=3 package_type=0  self.pid='0_24_2'> to <Packet version=7 package_type=1  self.pid='0_24'>
# Added <Packet version=7 package_type=1  self.pid='0_24'> to <Packet version=4 package_type=0  self.pid='0'>
# Creating packet 0_25 from ...
# Header of 0_25 self.version=4 self.package_type=1
# Must find 2 subpackets.
# Creating packet 0_25_0 from ...
# Header of 0_25_0 self.version=2 self.package_type=4
# Found a packet of type 4
# Searching block 11001
# Searching block 11101
# Searching block 10000
# Searching block 11111
# Searching block 10100
# Searching block 10110
# Searching block 11010
# Searching block 10001
# Searching block 10111
# Searching block 11001
# Searching block 01010
# Added <Packet version=2 package_type=4 10793058441114 self.pid='0_25_0'> to <Packet version=4 package_type=1  self.pid='0_25'>
# Creating packet 0_25_1 from ...
# Header of 0_25_1 self.version=7 self.package_type=5
# Must find 2 subpackets.
# Creating packet 0_25_1_0 from ...
# Header of 0_25_1_0 self.version=2 self.package_type=4
# Found a packet of type 4
# Searching block 10001
# Searching block 00001
# Added <Packet version=2 package_type=4 17 self.pid='0_25_1_0'> to <Packet version=7 package_type=5  self.pid='0_25_1'>
# Creating packet 0_25_1_1 from ...
# Header of 0_25_1_1 self.version=0 self.package_type=4
# Found a packet of type 4
# Searching block 10001
# Searching block 00001
# Added <Packet version=0 package_type=4 17 self.pid='0_25_1_1'> to <Packet version=7 package_type=5  self.pid='0_25_1'>
# Added <Packet version=7 package_type=5  self.pid='0_25_1'> to <Packet version=4 package_type=1  self.pid='0_25'>
# Added <Packet version=4 package_type=1  self.pid='0_25'> to <Packet version=4 package_type=0  self.pid='0'>
# Creating packet 0_26 from ...
# Header of 0_26 self.version=5 self.package_type=1
# Must find 2 subpackets.
# Creating packet 0_26_0 from ...
# Header of 0_26_0 self.version=7 self.package_type=4
# Found a packet of type 4
# Searching block 10010
# Searching block 01100
# Added <Packet version=7 package_type=4 44 self.pid='0_26_0'> to <Packet version=5 package_type=1  self.pid='0_26'>
# Creating packet 0_26_1 from ...
# Header of 0_26_1 self.version=1 self.package_type=5
# Creating packet 0_26_1_0 from 101100101111101010100011000111001101110011101111011010110111011011011010110111110001011
# Header of 0_26_1_0 self.version=5 self.package_type=4
# Found a packet of type 4
# Searching block 10111
# Searching block 11010
# Searching block 10100
# Searching block 01100
# Added <Packet version=5 package_type=4 31308 self.pid='0_26_1_0'> to <Packet version=1 package_type=5  self.pid='0_26_1'>
# Creating packet 0_26_1_1 from 0111001101110011101111011010110111011011011010110111110001011
# Header of 0_26_1_1 self.version=3 self.package_type=4
# Found a packet of type 4
# Searching block 11011
# Searching block 10011
# Searching block 10111
# Searching block 10110
# Searching block 10110
# Searching block 11101
# Searching block 10110
# Searching block 11010
# Searching block 11011
# Searching block 11100
# Searching block 01011
# Added <Packet version=3 package_type=4 12332576451531 self.pid='0_26_1_1'> to <Packet version=1 package_type=5  self.pid='0_26_1'>
# Added <Packet version=1 package_type=5  self.pid='0_26_1'> to <Packet version=5 package_type=1  self.pid='0_26'>
# Added <Packet version=5 package_type=1  self.pid='0_26'> to <Packet version=4 package_type=0  self.pid='0'>
# Creating packet 0_27 from ...
# Header of 0_27 self.version=1 self.package_type=4
# Found a packet of type 4
# Searching block 11011
# Searching block 11111
# Searching block 00010
# Added <Packet version=1 package_type=4 3058 self.pid='0_27'> to <Packet version=4 package_type=0  self.pid='0'>
# Creating packet 0_28 from ...
# Header of 0_28 self.version=7 self.package_type=0
# Creating packet 0_28_0 from 10010010010000010111001011011100100011100110101111101011000000
# Header of 0_28_0 self.version=4 self.package_type=4
# Found a packet of type 4
# Searching block 10010
# Searching block 00001
# Added <Packet version=4 package_type=4 33 self.pid='0_28_0'> to <Packet version=7 package_type=0  self.pid='0_28'>
# Creating packet 0_28_1 from 0111001011011100100011100110101111101011000000
# Header of 0_28_1 self.version=3 self.package_type=4
# Found a packet of type 4
# Searching block 10110
# Searching block 11100
# Searching block 10001
# Searching block 11001
# Searching block 10101
# Searching block 11110
# Searching block 10110
# Searching block 00000
# Added <Packet version=3 package_type=4 1813601888 self.pid='0_28_1'> to <Packet version=7 package_type=0  self.pid='0_28'>
# Added <Packet version=7 package_type=0  self.pid='0_28'> to <Packet version=4 package_type=0  self.pid='0'>
# Creating packet 0_29 from ...
# Header of 0_29 self.version=3 self.package_type=1
# Must find 4 subpackets.
# Creating packet 0_29_0 from ...
# Header of 0_29_0 self.version=2 self.package_type=4
# Found a packet of type 4
# Searching block 10110
# Searching block 01110
# Added <Packet version=2 package_type=4 110 self.pid='0_29_0'> to <Packet version=3 package_type=1  self.pid='0_29'>
# Creating packet 0_29_1 from ...
# Header of 0_29_1 self.version=3 self.package_type=4
# Found a packet of type 4
# Searching block 10011
# Searching block 01110
# Added <Packet version=3 package_type=4 62 self.pid='0_29_1'> to <Packet version=3 package_type=1  self.pid='0_29'>
# Creating packet 0_29_2 from ...
# Header of 0_29_2 self.version=4 self.package_type=4
# Found a packet of type 4
# Searching block 10010
# Searching block 01011
# Added <Packet version=4 package_type=4 43 self.pid='0_29_2'> to <Packet version=3 package_type=1  self.pid='0_29'>
# Creating packet 0_29_3 from ...
# Header of 0_29_3 self.version=2 self.package_type=4
# Found a packet of type 4
# Searching block 11101
# Searching block 01110
# Added <Packet version=2 package_type=4 222 self.pid='0_29_3'> to <Packet version=3 package_type=1  self.pid='0_29'>
# Added <Packet version=3 package_type=1  self.pid='0_29'> to <Packet version=4 package_type=0  self.pid='0'>
# Creating packet 0_30 from ...
# Header of 0_30 self.version=6 self.package_type=1
# Must find 2 subpackets.
# Creating packet 0_30_0 from ...
# Header of 0_30_0 self.version=2 self.package_type=4
# Found a packet of type 4
# Searching block 10111
# Searching block 00100
# Added <Packet version=2 package_type=4 116 self.pid='0_30_0'> to <Packet version=6 package_type=1  self.pid='0_30'>
# Creating packet 0_30_1 from ...
# Header of 0_30_1 self.version=3 self.package_type=4
# Found a packet of type 4
# Searching block 10101
# Searching block 01101
# Added <Packet version=3 package_type=4 93 self.pid='0_30_1'> to <Packet version=6 package_type=1  self.pid='0_30'>
# ...
# Added <Packet version=7 package_type=0  self.pid='0_42'> to <Packet version=4 package_type=0  self.pid='0'>
# Creating packet 0_43 from ...
# Header of 0_43 self.version=7 self.package_type=1
# Must find 2 subpackets.
# Creating packet 0_43_0 from ...
# Header of 0_43_0 self.version=6 self.package_type=7
# Must find 2 subpackets.
# Creating packet 0_43_0_0 from ...
# Header of 0_43_0_0 self.version=0 self.package_type=4
# Found a packet of type 4
# Searching block 11100
# Searching block 10010
# Searching block 10010
# Searching block 10011
# Searching block 11101
# Searching block 00011
# Added <Packet version=0 package_type=4 12723155 self.pid='0_43_0_0'> to <Packet version=6 package_type=7  self.pid='0_43_0'>
# Creating packet 0_43_0_1 from ...
# Header of 0_43_0_1 self.version=1 self.package_type=4
# Found a packet of type 4
# Searching block 11011
# Searching block 10000
# Searching block 10110
# Searching block 01010
# Added <Packet version=1 package_type=4 45162 self.pid='0_43_0_1'> to <Packet version=6 package_type=7  self.pid='0_43_0'>
# Added <Packet version=6 package_type=7  self.pid='0_43_0'> to <Packet version=7 package_type=1  self.pid='0_43'>
# Creating packet 0_43_1 from ...
# Header of 0_43_1 self.version=3 self.package_type=4
# Found a packet of type 4
# Searching block 11010
# Searching block 10000
# Searching block 11101
# Searching block 10101
# Searching block 10010
# Searching block 10100
# Searching block 10011
# Searching block 10011
# Searching block 10110
# Searching block 00100
# Added <Packet version=3 package_type=4 690770686820 self.pid='0_43_1'> to <Packet version=7 package_type=1  self.pid='0_43'>
# Added <Packet version=7 package_type=1  self.pid='0_43'> to <Packet version=4 package_type=0  self.pid='0'>
# Creating packet 0_44 from ...
# Header of 0_44 self.version=5 self.package_type=3
# Creating packet 0_44_0 from 0001001101001111
# Header of 0_44_0 self.version=0 self.package_type=4
# Found a packet of type 4
# Searching block 11010
# Searching block 01111
# Added <Packet version=0 package_type=4 175 self.pid='0_44_0'> to <Packet version=5 package_type=3  self.pid='0_44'>
# Added <Packet version=5 package_type=3  self.pid='0_44'> to <Packet version=4 package_type=0  self.pid='0'>
# Creating packet 0_45 from ...
# Header of 0_45 self.version=0 self.package_type=3
# Creating packet 0_45_0 from 11010001101110100111100011110010010111101111001011001111111100101000
# Header of 0_45_0 self.version=6 self.package_type=4
# Found a packet of type 4
# Searching block 01101
# Added <Packet version=6 package_type=4 13 self.pid='0_45_0'> to <Packet version=0 package_type=3  self.pid='0_45'>
# Creating packet 0_45_1 from 110100111100011110010010111101111001011001111111100101000
# Header of 0_45_1 self.version=6 self.package_type=4
# Found a packet of type 4
# Searching block 11110
# Searching block 00111
# Added <Packet version=6 package_type=4 231 self.pid='0_45_1'> to <Packet version=0 package_type=3  self.pid='0_45'>
# Creating packet 0_45_2 from 10010010111101111001011001111111100101000
# Header of 0_45_2 self.version=4 self.package_type=4
# Found a packet of type 4
# Searching block 10111
# Searching block 10111
# Searching block 10010
# Searching block 11001
# Searching block 11111
# Searching block 11001
# Searching block 01000
# Added <Packet version=4 package_type=4 124952472 self.pid='0_45_2'> to <Packet version=0 package_type=3  self.pid='0_45'>
# Added <Packet version=0 package_type=3  self.pid='0_45'> to <Packet version=4 package_type=0  self.pid='0'>
# Creating packet 0_46 from ...
# Header of 0_46 self.version=5 self.package_type=1
# Must find 2 subpackets.
# Creating packet 0_46_0 from ...
# Header of 0_46_0 self.version=0 self.package_type=4
# Found a packet of type 4
# Searching block 10010
# Searching block 11001
# Searching block 11110
# Searching block 11001
# Searching block 11001
# Searching block 00101
# Added <Packet version=0 package_type=4 2746773 self.pid='0_46_0'> to <Packet version=5 package_type=1  self.pid='0_46'>
# Creating packet 0_46_1 from ...
# Header of 0_46_1 self.version=6 self.package_type=5
# Creating packet 0_46_1_0 from 100100101101111110001100001001000000100100100011110001000
# Header of 0_46_1_0 self.version=4 self.package_type=4
# Found a packet of type 4
# Searching block 10110
# Searching block 11111
# Searching block 10001
# Searching block 10000
# Searching block 10010
# Searching block 00000
# Added <Packet version=4 package_type=4 7278624 self.pid='0_46_1_0'> to <Packet version=6 package_type=5  self.pid='0_46_1'>
# Creating packet 0_46_1_1 from 100100100011110001000
# Header of 0_46_1_1 self.version=4 self.package_type=4
# Found a packet of type 4
# Searching block 10001
# Searching block 11100
# Searching block 01000
# Added <Packet version=4 package_type=4 456 self.pid='0_46_1_1'> to <Packet version=6 package_type=5  self.pid='0_46_1'>
# Added <Packet version=6 package_type=5  self.pid='0_46_1'> to <Packet version=5 package_type=1  self.pid='0_46'>
# Added <Packet version=5 package_type=1  self.pid='0_46'> to <Packet version=4 package_type=0  self.pid='0'>
# Creating packet 0_47 from ...
# Header of 0_47 self.version=5 self.package_type=1
# Must find 5 subpackets.
# Creating packet 0_47_0 from ...
# Header of 0_47_0 self.version=7 self.package_type=4
# Found a packet of type 4
# Searching block 11111
# Searching block 01101
# Added <Packet version=7 package_type=4 253 self.pid='0_47_0'> to <Packet version=5 package_type=1  self.pid='0_47'>
# Creating packet 0_47_1 from ...
# Header of 0_47_1 self.version=2 self.package_type=4
# Found a packet of type 4
# Searching block 10101
# Searching block 00000
# Added <Packet version=2 package_type=4 80 self.pid='0_47_1'> to <Packet version=5 package_type=1  self.pid='0_47'>
# Creating packet 0_47_2 from ...
# Header of 0_47_2 self.version=3 self.package_type=4
# Found a packet of type 4
# Searching block 11010
# Searching block 01001
# Added <Packet version=3 package_type=4 169 self.pid='0_47_2'> to <Packet version=5 package_type=1  self.pid='0_47'>
# Creating packet 0_47_3 from ...
# Header of 0_47_3 self.version=5 self.package_type=4
# Found a packet of type 4
# Searching block 00110
# Added <Packet version=5 package_type=4 6 self.pid='0_47_3'> to <Packet version=5 package_type=1  self.pid='0_47'>
# Creating packet 0_47_4 from ...
# Header of 0_47_4 self.version=2 self.package_type=4
# Found a packet of type 4
# Searching block 11100
# Searching block 01100
# Added <Packet version=2 package_type=4 204 self.pid='0_47_4'> to <Packet version=5 package_type=1  self.pid='0_47'>
# Added <Packet version=5 package_type=1  self.pid='0_47'> to <Packet version=4 package_type=0  self.pid='0'>
# Creating packet 0_48 from ...
# Header of 0_48 self.version=2 self.package_type=1
# Must find 2 subpackets.
# Creating packet 0_48_0 from ...
# Header of 0_48_0 self.version=6 self.package_type=6
# Creating packet 0_48_0_0 from 1011001011100011111100100111111010001110001000101010
# Header of 0_48_0_0 self.version=5 self.package_type=4
# Found a packet of type 4
# Searching block 10111
# Searching block 00011
# Added <Packet version=5 package_type=4 115 self.pid='0_48_0_0'> to <Packet version=6 package_type=6  self.pid='0_48_0'>
# Creating packet 0_48_0_1 from 111100100111111010001110001000101010
# Header of 0_48_0_1 self.version=7 self.package_type=4
# Found a packet of type 4
# Searching block 10011
# Searching block 11110
# Searching block 10001
# Searching block 11000
# Searching block 10001
# Searching block 01010
# Added <Packet version=7 package_type=4 4069402 self.pid='0_48_0_1'> to <Packet version=6 package_type=6  self.pid='0_48_0'>
# Added <Packet version=6 package_type=6  self.pid='0_48_0'> to <Packet version=2 package_type=1  self.pid='0_48'>
# Creating packet 0_48_1 from ...
# Header of 0_48_1 self.version=0 self.package_type=4
# Found a packet of type 4
# Searching block 11011
# Searching block 11011
# Searching block 11101
# Searching block 10001
# Searching block 11001
# Searching block 01100
# Added <Packet version=0 package_type=4 12308892 self.pid='0_48_1'> to <Packet version=2 package_type=1  self.pid='0_48'>
# Added <Packet version=2 package_type=1  self.pid='0_48'> to <Packet version=4 package_type=0  self.pid='0'>
# Creating packet 0_49 from ...
# Header of 0_49 self.version=5 self.package_type=4
# Found a packet of type 4
# Searching block 10111
# Searching block 10010
# Searching block 11110
# Searching block 11110
# Searching block 10011
# Searching block 11010
# Searching block 01110
# Added <Packet version=5 package_type=4 120513454 self.pid='0_49'> to <Packet version=4 package_type=0  self.pid='0'>
# Creating packet 0_50 from 
# Header of 0_50 self.version=2 self.package_type=1
# Creating packet 0_50_0 from 11010110000000001010010011000110101100111110111001101000110011100111111001010001100001101100111110100101101111000101
# Header of 0_50_0 self.version=6 self.package_type=5
# Must find 2 subpackets.
# Creating packet 0_50_0_0 from 10010011000110101100111110111001101000110011100111111001010001100001101100111110100101101111000101
# Header of 0_50_0_0 self.version=4 self.package_type=4
# Found a packet of type 4
# Searching block 11000
# Searching block 11010
# Searching block 11001
# Searching block 11110
# Searching block 11100
# Searching block 11010
# Searching block 00110
# Added <Packet version=4 package_type=4 145353894 self.pid='0_50_0_0'> to <Packet version=6 package_type=5  self.pid='0_50_0'>
# Creating packet 0_50_0_1 from 011100111111001010001100001101100111110100101101111000101
# Header of 0_50_0_1 self.version=3 self.package_type=4
# Found a packet of type 4
# Searching block 11111
# Searching block 10010
# Searching block 10001
# Searching block 10000
# Searching block 11011
# Searching block 00111
# Added <Packet version=3 package_type=4 15863991 self.pid='0_50_0_1'> to <Packet version=6 package_type=5  self.pid='0_50_0'>
# Added <Packet version=6 package_type=5  self.pid='0_50_0'> to <Packet version=2 package_type=1  self.pid='0_50'>
# Creating packet 0_50_1 from 110100101101111000101
# Header of 0_50_1 self.version=6 self.package_type=4
# Found a packet of type 4
# Searching block 10110
# Searching block 11110
# Searching block 00101
# Added <Packet version=6 package_type=4 1765 self.pid='0_50_1'> to <Packet version=2 package_type=1  self.pid='0_50'>
# Added <Packet version=2 package_type=1  self.pid='0_50'> to <Packet version=4 package_type=0  self.pid='0'>
# Creating packet 0_51 from 11100110000000001010010010101101011010100110010110100000000010011000100000000011001100011011111000101010010000100110000100000000011110100010001001000010001110001110101010100000000010101100111000001101110011011110011111010011101001001001011
# Header of 0_51 self.version=7 self.package_type=1
# Must find 2 subpackets.
# Creating packet 0_51_0 from 10010010101101011010100110010110100000000010011000100000000011001100011011111000101010010000100110000100000000011110100010001001000010001110001110101010100000000010101100111000001101110011011110011111010011101001001001011
# Header of 0_51_0 self.version=4 self.package_type=4
# Found a packet of type 4
# Searching block 10101
# Searching block 10101
# Searching block 10101
# Searching block 00110
# Added <Packet version=4 package_type=4 21846 self.pid='0_51_0'> to <Packet version=7 package_type=1  self.pid='0_51'>
# Creating packet 0_51_1 from 010110100000000010011000100000000011001100011011111000101010010000100110000100000000011110100010001001000010001110001110101010100000000010101100111000001101110011011110011111010011101001001001011
# Header of 0_51_1 self.version=2 self.package_type=6
# Must find 2 subpackets.
# Creating packet 0_51_1_0 from 011000100000000011001100011011111000101010010000100110000100000000011110100010001001000010001110001110101010100000000010101100111000001101110011011110011111010011101001001001011
# Header of 0_51_1_0 self.version=3 self.package_type=0
# Must find 3 subpackets.
# Creating packet 0_51_1_0_0 from 001100011011111000101010010000100110000100000000011110100010001001000010001110001110101010100000000010101100111000001101110011011110011111010011101001001001011
# Header of 0_51_1_0_0 self.version=1 self.package_type=4
# Found a packet of type 4
# Searching block 01101
# Added <Packet version=1 package_type=4 13 self.pid='0_51_1_0_0'> to <Packet version=3 package_type=0  self.pid='0_51_1_0'>
# Creating packet 0_51_1_0_1 from 1111000101010010000100110000100000000011110100010001001000010001110001110101010100000000010101100111000001101110011011110011111010011101001001001011
# Header of 0_51_1_0_1 self.version=7 self.package_type=4
# Found a packet of type 4
# Searching block 01010
# Added <Packet version=7 package_type=4 10 self.pid='0_51_1_0_1'> to <Packet version=3 package_type=0  self.pid='0_51_1_0'>
# Creating packet 0_51_1_0_2 from 10010000100110000100000000011110100010001001000010001110001110101010100000000010101100111000001101110011011110011111010011101001001001011
# Header of 0_51_1_0_2 self.version=4 self.package_type=4
# Found a packet of type 4
# Searching block 00100
# Added <Packet version=4 package_type=4 4 self.pid='0_51_1_0_2'> to <Packet version=3 package_type=0  self.pid='0_51_1_0'>
# Added <Packet version=3 package_type=0  self.pid='0_51_1_0'> to <Packet version=2 package_type=6  self.pid='0_51_1'>
# Creating packet 0_51_1_1 from 110000100000000011110100010001001000010001110001110101010100000000010101100111000001101110011011110011111010011101001001001011
# Header of 0_51_1_1 self.version=6 self.package_type=0
# Must find 3 subpackets.
# Creating packet 0_51_1_1_0 from 110100010001001000010001110001110101010100000000010101100111000001101110011011110011111010011101001001001011
# Header of 0_51_1_1_0 self.version=6 self.package_type=4
# Found a packet of type 4
# Searching block 01000
# Added <Packet version=6 package_type=4 8 self.pid='0_51_1_1_0'> to <Packet version=6 package_type=0  self.pid='0_51_1_1'>
# Creating packet 0_51_1_1_1 from 1001000010001110001110101010100000000010101100111000001101110011011110011111010011101001001001011
# Header of 0_51_1_1_1 self.version=4 self.package_type=4
# Found a packet of type 4
# Searching block 00100
# Added <Packet version=4 package_type=4 4 self.pid='0_51_1_1_1'> to <Packet version=6 package_type=0  self.pid='0_51_1_1'>
# Creating packet 0_51_1_1_2 from 01110001110101010100000000010101100111000001101110011011110011111010011101001001001011
# Header of 0_51_1_1_2 self.version=3 self.package_type=4
# Found a packet of type 4
# Searching block 01110
# Added <Packet version=3 package_type=4 14 self.pid='0_51_1_1_2'> to <Packet version=6 package_type=0  self.pid='0_51_1_1'>
# Added <Packet version=6 package_type=0  self.pid='0_51_1_1'> to <Packet version=2 package_type=6  self.pid='0_51_1'>
# Added <Packet version=2 package_type=6  self.pid='0_51_1'> to <Packet version=7 package_type=1  self.pid='0_51'>
# Added <Packet version=7 package_type=1  self.pid='0_51'> to <Packet version=4 package_type=0  self.pid='0'>
# Creating packet 0_52 from 101010100000000010101100111000001101110011011110011111010011101001001001011
# Header of 0_52 self.version=5 self.package_type=2
# Must find 2 subpackets.
# Creating packet 0_52_0 from 101100111000001101110011011110011111010011101001001001011
# Header of 0_52_0 self.version=5 self.package_type=4
# Found a packet of type 4
# Searching block 11100
# Searching block 00011
# Added <Packet version=5 package_type=4 195 self.pid='0_52_0'> to <Packet version=5 package_type=2  self.pid='0_52'>
# Creating packet 0_52_1 from 01110011011110011111010011101001001001011
# Header of 0_52_1 self.version=3 self.package_type=4
# Found a packet of type 4
# Searching block 11011
# Searching block 11001
# Searching block 11110
# Searching block 10011
# Searching block 10100
# Searching block 10010
# Searching block 01011
# Added <Packet version=3 package_type=4 194917419 self.pid='0_52_1'> to <Packet version=5 package_type=2  self.pid='0_52'>
# Added <Packet version=5 package_type=2  self.pid='0_52'> to <Packet version=4 package_type=0  self.pid='0'>
# 834151779165
